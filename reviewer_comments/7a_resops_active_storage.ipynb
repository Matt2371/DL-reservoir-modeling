# %% [markdown]
# ### Active Storage (max storage - min storage) vs Max Storage

# %%
import os
print(f"Current Directory: {os.getcwd()}")
os.chdir("..")
print(f"New Directory: {os.getcwd()}")
# Out:
# Current Directory: c:\Users\mattc\Documents\DL-reservoir-modeling\reviewer_comments
# New Directory: c:\Users\mattc\Documents\DL-reservoir-modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('report/results/resops_training/resops_attributes_r2.csv', index_col=0)

print(f'Correlation between estimated active storage (max-min) and max storage: {round(np.corrcoef(df['max_storage'], (df['max_storage'] - df['min_storage']))[0, 1], 3)}')
# Out:
# Correlation between estimated active storage (max-min) and max storage: 0.99
